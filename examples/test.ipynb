# %%
from daedalus.core.flow_graph import build_flow_graph

# Minimal test
import pandas as pd

df = pd.DataFrame({
    'source': ['Gov', 'FirmA'],
    'target': ['Household', 'Gov'],
    'value': [200, 150]
})

G = build_flow_graph(df)
print(G.edges(data=True))
